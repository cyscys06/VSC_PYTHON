# %% [markdown]
# # Chapter 03 조건문

# %% [markdown]
# Chapter 03 조건문
# - 3.1 이번 장에서 만들 프로그램
# - 3.2 제어문
# - 3.3 if-else 문
# - 3.4 관계 연산자
#     - Lab 산술 퀴즈 프로그램
# - 3.5 조건 연산자
#     - Lab 짝수와 홀수를 구분해보자
#     - Lab 세일 가격 계산
# - 3.6 논리 연산자
#     - Lab 물의 상태 출력하기
#     - Lab 동전 던지기 게임
#     - Lab 거북이 제어하기
# - 3.7 중첩 if 문
# - 3.8 연속 if 문
#     - Lab 리히터 규모
#     - Lab 매직볼
#     - Lab 사용자 입력 검증하기
#     - Lab 축구게임
#     - Lab 도형 그리기
#     - Lab 올바른 삼각형 구별하기

# %% [markdown]
# 학습목표
# - 제어문에 대하여 이해합니다.
# - if-else 문을 이해하고 사용할 수 있습니다.
# - 관계연산자와 논리연산자를 학습합니다.
# - 블록의 개념을 학습합니다.
# - 중첩 if-else 문을 학습합니다.
# - 연속 if-else 문을 학습합니다.

# %% [markdown]
# ## 3.1 이번 장에서 만들 프로그램

# %% [markdown]
# ## 3.2 제어문
#
# 프로그램으로 현실 세계의 복잡한 문제를 처리하려면 조건에 따라서 실행을 다르게 하거나 조건에 따라 반복할 수 있어야 한다.
#
# - 순차구조(sequence): 명령들이 순차적으로 실행되는 구조
# - 선택구조(selection): 둘 중의 하나의 명령을 선택하여 실행되는 구조, 조건문으로 구현됨
# - 반복구조(iteration): 동일한 명령이 반복되면서 실행되는 구조, 반복문으로 구현됨
#
# ![image.png](attachment:500d280e-bd75-4be5-8180-65cd53d352d0.png)

# %% [markdown]
# ## 3.3 if-else 문

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 배송비 계산 프로그램

# %%
# %load shopping.py
# 사용자로부터 상품의 가격을 입력받는다.  
price = int(input("상품의 가격: "))    # 30000

# 배송비를 결정한다. 
if  price > 20000 :
	shipping_cost = 0
else :
	shipping_cost = 3000

# 배송비를 출력한다. 
print("배송비 = ", shipping_cost)
# Out:
# 상품의 가격: 30000
# 배송비 =  0

# %%
# 주석문을 제외한 순수 코드를 손코딩으로 입력하고 실행해 보세요.

# %% [markdown]
# ### 블록
#
# - 여러 문장들을 묶은 것

# %%
price = 30000

# %%
# 들여쓰기 4칸 적용: OK
if  price > 20000 :
    shipping_cost = 0
    discount = 0.1
else :
    shipping_cost = 3000

# %%
# 주석문을 제외한 순수 코드를 손코딩으로 입력하고 실행해 보세요.

# %% [markdown]
# 블록내 동일한 개수의 공백이 있으면 같은 블록으로 처리: OK

# %%
# 들여쓰기 2칸 적용: OK,
if  price > 20000 :
  shipping_cost = 0
  discount = 0.1
else :
    shipping_cost = 3000

# %% [markdown]
# 블록내 동일한 개수의 공백이 사용되지 않으면 오류: IndentationError

# %%
# 들여쓰기 4칸, 2칸 적용
if  price > 20000 :
    shipping_cost = 0
  discount = 0.1
else :
  shipping_cost = 3000
# Out:
#   File <tokenize>:4
#     discount = 0.1
#     ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# ### else는 없을 수도 있다.

# %%
shipping_cost = 3000		# 기본적으로 배송비는 3000원이다. 
if  price > 20000 :			# 만약 상품의 가격이 2만원 초과이면
	shipping_cost = 0		# 배송비가 없다.

# %% [markdown]
# #### Pass keyword

# %%
if  price > 20000 :
    pass  # 아직 미구현 상태, 블럭을 비워두면 Error
else : 
    pass  # 아직 미구현 상태

# %%
if  price > 20000 :
    #pass   #블럭을 비워두면 Error
    
print('next sentence')
# Out:
#   Cell In[20], line 4
#     print('next sentence')
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %% [markdown]
# ## 3.4 관계 연산자
#
# ![image.png](attachment:a9971dd7-c7dd-4a66-a2b9-7dda173f2d42.png)

# %% [markdown]
# ### 부울 변수
# - 관계 연산자의 결과값은 True 아니면 False인 부울값(Boolean value)임

# %%
radius = 100
flag = (radius > 32)
print(flag)
# Out:
# True

# %%
# 주석문을 제외한 순수 코드를 손코딩으로 입력하고 실행해 보세요.

# %%
expensive = price > 20000 	# expensive가 부울 변수이다. 
if  expensive :		# 관계 수식 대신에 부울 변수가 들어가도 된다. 
	shipping_cost = 0
else :
	shipping_cost = 3000

# %%
# 주석문을 제외한 순수 코드를 손코딩으로 입력하고 실행해 보세요.

# %%
price
# Out:
# 30000

# %%
shipping_cost
# Out:
# 0

# %% [markdown]
# ### 문장열 비교

# %% [markdown]
# 완전히 같아야 True

# %%
s1 = "Audrey Hepburn"
s2 = "Audrey Hepburn"
print(s1 == s2)
# Out:
# True

# %% [markdown]
# 사전에서의 순서

# %%
s1 = "Audrey Hepburn"
s2 = "Grace Kelly"
print(s1 < s2)
# Out:
# True

# %%
# 주석문을 제외한 순수 코드를 손코딩으로 입력하고 실행해 보세요.

# %% [markdown]
# - 대문자는 소문자보다 앞에 있는 것으로 간주됨
# - 스페이스 문자는 모든 알파벳 문자보다 앞에 있는 것으로 간주됨
# - 숫자는 문자보다 앞에 있음

# %% [markdown]
# ### 실수와 실수의 비교

# %%
from math import sqrt

n = sqrt(3.0)
if n*n == 3.0 :
	print("sqrt(3.0)*sqrt(3.0)은 3.0과 같다. ")
else :
	print("sqrt(3.0)*sqrt(3.0)은 3.0과 같지 않다. ")
# Out:
# sqrt(3.0)*sqrt(3.0)은 3.0과 같지 않다.

# %%
# 주석문을 제외한 순수 코드를 손코딩으로 입력하고 실행해 보세요.

# %% [markdown]
# 컴퓨터에서는 비트의 수가 제한되어 있으므로 복잡한 값은 정확하게 표현되지 않기 때문에 발생함
#
# 오차 이내로 아주 근접하면 같은 것으로 판정

# %%
if abs(n*n - 3.0) < 0.00001 :
	print("sqrt(3.0)*sqrt(3.0)은 3.0과 같다. ")
# Out:
# sqrt(3.0)*sqrt(3.0)은 3.0과 같다.

# %% [markdown]
# ### Lab 산술 퀴즈 프로그램

# %% [markdown]
# - 초등학생들을 위하여 산수 퀴즈를 발생시키는 프로그램을 작성해보자

# %% [markdown]
#  random.randint(1, 100)
#  - 1부터 100 사이의 난수 생성  (1~100도 포함)

# %% [markdown]
# 헷갈리니 여기서 간략히 한번 살펴볼 것
# - https://blockdmask.tistory.com/383

# %%
# %load mathprob.py
##
#	이 프로그램은 산수 문제를 출제한다.  
#

import random

x = random.randint(1, 100)    # 1부터 100 사이의 난수 생성
y = random.randint(1, 100)

answer = int(input(f"{x} + {y} = "))

# 부울 변수에 결과를 저장하고 출력한다. 
flag = (answer == (x+y))
print(flag)
# Out:
# 60 + 85 = 100
# False

# %% [markdown]
# ## 3.5 조건 연산자
#
# 조건 연산자를 감싸는 괄호가 있어야 함
# - 괄호가 없으면 할당 연산자가 먼저 계산 됨

# %%
price = 30000

# %%
shipping_cost = ( 0 if price >= 20000 else 3000 )

absolute_value = (x if x > 0 else -x) # 절대값 계산
max_value = (x if x > y else y)       # 최대값 계산
min_value = (x if x < y else y)       # 최소값 계산

# %%
print(absolute_value, max_value, min_value)
# Out:
# 60 85 60

# %% [markdown]
# 예제

# %%
x = int(input("첫 번째 수 ="))   # 10
y = int(input("두 번째 수 ="))   # 20
max_value = (x if x > y else y)
min_value = (y if x > y else x)
print("큰 수=", max_value, "작은 수=", min_value)
# Out:
# 첫 번째 수 =10
# 두 번째 수 =20
# 큰 수= 20 작은 수= 10

# %%
# 좀 어렵지만 하나씩 따져봅시다.

# %% [markdown]
# ### Lab 짝수와 홀수를 구분해보자
# - 사용자로부터 정수를 입력받아서 짝수인지 홀수인지를 검사하는 프로그램을 작성해보자
# - 짝수와 홀수 구분은 나머지를 계산하는 연산자 사용

# %%
number = int(input("정수를 입력하시오: "))   # 문자열을 정수로 변환

if number % 2 == 0 :
    print("짝수입니다.")
else:
    print("홀수입니다.")
# Out:
# 정수를 입력하시오: 12
# 짝수입니다.

# %%
# 주석문을 제외한 순수 코드를 손코딩으로 입력하고 실행해 보세요.

# %% [markdown]
# ### Lab 세일 가격 계산
# - 상품의 가격이 100만원 미만이면 10% 할인이 적용된다. 만약 상품의 가격이 100만원 이상이면 15%의 할인이 적용된다. 그리고 100만원 이상의 상품을 사면 사은품이 지급된다. 100만원 미만이면 사은품은 없다

# %%
price = int(input("정가를 입력하시오: "))   # 200, 80
if price >= 100 :
    dis_rate = 0.85
    print("10층에서 사은품을 받아가세요.")
else :
    dis_rate = 0.90
dis_price = dis_rate * price
print("할인된 상품의 가격=", dis_price)
# Out:
# 정가를 입력하시오: 80
# 할인된 상품의 가격= 72.0

# %%
# 주석문을 제외한 순수 코드를 손코딩으로 입력하고 실행해 보세요.
# 꼼꼼하게 하나씩 따져 봅시다.

# %% [markdown]
# ## 3.6 논리 연산자
# - 복잡한 조건을 표현하려면 논리 연산자를 사용
# - https://en.wikipedia.org/wiki/Truth_table
#
#   ![image.png](attachment:391d00f6-d60f-4eff-a9c3-02dd99854979.png)

# %%
price = int(input("가격을 입력하시오: "))   # 30000
card = input("카드 종류를 입력하시오: ")    # python, java

if price > 20000 and card == "python": # 파이썬의 논리 연산자에는 and, or, not 3개가 있다.
    print("배송료가 없습니다.")
else:
    print("배송료는 3000원입니다.")
# Out:
# 가격을 입력하시오:  123123123
# 카드 종류를 입력하시오:  qwe
# 배송료는 3000원입니다.

# %% [markdown]
# ### 드 모르간의 법칙
# - 인간은 일반적으로 not 연산자가 적용된 수식을 이해하기가 어렵다. 논리 학자 드모르간(De Morgan)의 이름을 딴 드모르간의 법칙을 사용하여 이러한 논리식을 단순화할 수 있다
# - https://en.wikipedia.org/wiki/De_Morgan%27s_laws

# %%
country = "한국"
province = "제주"

# %%
if not (country == "한국" and province != "제주") :
    shipping_cost = 8000

shipping_cost
# Out:
# 8000

# %%
if not (country == "한국" and province != "제주") :
    shipping_cost = 8000

shipping_cost
# Out:
# 8000

# %% [markdown]
# ### Lab 물의 상태 출력하기
# - 사용자로부터 온도를 입력받아서 현재 물의 상태를 출력하는 프로그램을 작성해보자

# %%
# %load water_state.py
##
#	이 프로그램은 온도에 따른 물의 상태를 출력한다. 
#
temp = float(input("온도를 입력하시오: "))    # 30

if temp <= 0 :
	print("물의 상태는 얼음입니다.")
elif temp > 0 and temp < 100 :		# 논리 연산자를 사용한다. 
	print("물의 상태는 액체입니다.")
else :
	print("물의 상태는 기체입니다.")
# Out:
# 온도를 입력하시오: 30
# 물의 상태는 액체입니다.

# %%
# 주석문을 제외한 순수 코드를 손코딩으로 입력하고 실행해 보세요.

# %% [markdown]
# ### Lab 동전 던지기 게임
# - 동전을 던지기 게임을 작성해보자
#     - random.randrange(2): 0이나 1을 램덤하게 생성함  (2는 포함 안 됨)

# %%
import random

print("동전 던지기 게임을 시작합니다.")

coin = random.randrange(2)

if coin == 0 :
	print("앞면입니다.")
else :
	print("뒷면입니다.")

print("게임이 종료되었습니다.")
# Out:
# 동전 던지기 게임을 시작합니다.
# 앞면입니다.
# 게임이 종료되었습니다.

# %% [markdown]
# ### Lab 거북이 제어하기   => skip

# %% [markdown]
# ## 3.7 중첩 if 문
# - if 문 안에 다른 if 문이 들어갈 수도 있다. 이것을 중첩 if 문이라고 한다
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 배송비 계산 프로그램
#
# - 배송지가 한국이면 다음과 같이 배송비가 결정된다. - ”상품의 가격이 2만원 이상이면 배송비는 없고 그렇지 않으면 3000원의 배송비가 붙는다.“
# - 배송지가 미국이면 다음과 같이 배송비가 결정된다. - ”상품의 가격이 10만원 이상이면 배송비는 없고 그렇지 않으면 8000원의 배송비가 붙는다.“

# %%
# %load shopping2(p137).py
# 사용자로부터 상품의 가격을 입력받는다.  
country = input("배송지(현재는 korea와 us만 가능): ")   # us
price = int(input("상품의 가격: "))   # 12000

# 배송비를 결정한다. 
if  country == "korea" :
	if  price >= 20000 :
		shipping_cost = 0
	else :
		shipping_cost = 3000
else :
	if  price >= 100000 :
		shipping_cost = 0
	else :
		shipping_cost = 8000

# 배송비를 출력한다. 
print("배송비 = ", shipping_cost)
# Out:
# 배송지(현재는 korea와 us만 가능): us
# 상품의 가격: 12000
# 배송비 =  8000

# %%
# 주석문을 제외한 순수 코드를 손코딩으로 입력하고 실행해 보세요.
# 프로그램의 흐름을 쫒아갈 수 있을까요?

# %% [markdown]
# ## 3.8 연속 if 문

# %% [markdown]
# 학점 결정 예제

# %%
# 성적을 받아서 학점을 결정하는 프로그램

#score가 80 이상, 90 미만인 경우
score = int(input("성적을 입력하시오: "))

if score >= 90 :
	print("학점 A")
elif score >= 80 :
	print("학점 B")
elif score >= 70 :
	print("학점 C")
elif score >= 60 :
	print("학점 D")
else :
	print("학점 F")
# Out:
# 성적을 입력하시오: 88
# 학점 B

# %%
# 주석문을 제외한 순수 코드를 손코딩으로 입력하고 실행해 보세요.

# %% [markdown]
# ### Lab 리히터 규모
# - 사용자로부터 지진의 리히터 규모를 받아서 그 영향을 출력하는 프로그램을 작성
#
# ![image-2.png](attachment:image-2.png)

# %%
# %load earthquake.py
##
#	이 프로그램은 리히터 규모를 받아서 피해정도를 출력한다. 
#
scale = float(input("리히터 규모를 입력하시오: "))  # 5.2

if scale >= 8.0 :
	print("대부분의 구조물이 파괴됩니다. ")
elif scale >= 7.0 :
	print("지표면에 균열이 발생합니다.")
elif scale >= 4.0 :
	print("빈약한 건물에 큰 피해가 있습니다. ")
elif scale >= 2.0 :
	print("물건들이 흔들리거나 떨어집니다.")
else :
	print("지진계에 의해서만 탐지 가능합니다. ")
# Out:
# 리히터 규모를 입력하시오: 5.2
# 빈약한 건물에 큰 피해가 있습니다.

# %% [markdown]
# ### Lab 매직볼
# - 조건문을 이용하여서 오늘의 운세를 알려주는 프로그램을 개발해보자.
# - random.randint(1,8): 1부터 8사이의 난수를 생성 (8은 포함됨)

# %%
# %load magic_ball.py
##
#	이 프로그램은 오늘의 운세를 출력한다. 
#
import random

print("행운의 매직볼로 오늘의 운세를 출력합니다. ")
answers = random.randint(1, 8)
if answers == 1:
    print("확실히 이루어집니다.")
elif answers == 2:
    print("좋아 보이네요")
elif answers == 3:
    print("믿으셔도 됩니다.")
elif answers == 4:
    print("저의 생각에는 no입니다.")
else: 
    print("다시 질문해주세요.")
# Out:
# 행운의 매직볼로 오늘의 운세를 출력합니다.
# 믿으셔도 됩니다.

# %% [markdown]
# ### Lab 사용자 입력 검증하기
# - 사용자가 선택할 수 있는 메뉴를 1번부터 3번까지 출력하고 사용자가 입력한 값이 1부터 3 사이에 있는지를 if 문으로 검사해보자

# %%
# %load user_input.py
##
#	이 프로그램은 사용자의 입력을 검증한다. 
#
print("========================")
print("메뉴 1번: 치즈 버거")
print("메뉴 2번: 치킨 버거")
print("메뉴 3번: 불고기 버거")
print("========================")

selection = int(input("메뉴를 선택하세요:"))

if selection >= 1 and selection <= 3 :
	print("메뉴 ", selection)
else :
	print("잘못 입력하셨습니다.")
# Out:
# ...
# 메뉴 1번: 치즈 버거
# 메뉴 2번: 치킨 버거
# 메뉴 3번: 불고기 버거
# ...
# 메뉴를 선택하세요:4
# 잘못 입력하셨습니다.

# %% [markdown]
# ### Lab 축구게임
# - 난수를 이용하여 간단한 축구 게임을 작성하여 보자. 사용자가 컴퓨터를 상대로 페날티킥을 한다고 생각하자. 사용자는 다음의 3가지 영역 중에서 하나를 선택하여 페날티킥을 한다. 컴퓨터도 난수를 생성하여 3개의 영역 중 에서 하나를 수비한다

# %%
# %load soccer.py
##
#	이 프로그램은 축구 게임을 구현한다. 
#
import random

computer_choice = random.randint(1, 3)
print('computer choice: ', computer_choice)
user_choice = int(input("어디를 수비하시겠어요?(왼쪽: 1, 중앙: 2, 오른쪽: 3): "))
if computer_choice == user_choice:
	print("수비에 성공하셨습니다. ")
else:
	print("페날티킥이 성공하였습니다. ")
# Out:
# computer choice:  2
# 어디를 수비하시겠어요?(왼쪽: 1, 중앙: 2, 오른쪽: 3): 1
# 페날티킥이 성공하였습니다.

# %% [markdown]
# ### Lab 도형 그리기 => skip

# %% [markdown]
# ### Lab 올바른 삼각형 구별하기
# - 사용자로부터 삼각형 변의 길이를 받아서 유효한 삼각형인지를 검사하는 프로그램을 작성하라

# %%
# %load triangle.py
a = int(input("삼각형의 한 변을 입력하시오: "))  # 8
b = int(input("삼각형의 한 변을 입력하시오: "))  # 10
c = int(input("삼각형의 한 변을 입력하시오: "))  # 3
if (a + b) > c and (b + c) > a and (a + c) > b :
	print("올바른 삼각형")
else :
	print("올바르지 않은 삼각형")
# Out:
# 삼각형의 한 변을 입력하시오: 8
# 삼각형의 한 변을 입력하시오: 10
# 삼각형의 한 변을 입력하시오: 3
# 올바른 삼각형

# %% [markdown]
# --- 3장 종료 ---
