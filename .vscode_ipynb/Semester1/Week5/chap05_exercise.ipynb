# %% [markdown]
# # Chapter 05 함수

# %% [markdown]
# Chapter 05 함수
# - 5.1 이번 장에서 만들 프로그램
# - 5.2 함수란?
# - 5.3 함수 작성하고 호출하기
# - 5.4 여러 개의 함수가 있는 프로그램
#     - Lab 피자 크기 비교
# - 5.5 매개 변수 전달
#     - Lab 환영 문자열 출력 함수
#     - Lab 이분법
#     - Lab 주급 계산 프로그램
# - 5.6 값 반환하기
#     - Lab 여러 개의 값 반환
# - 5.7 함수를 사용하는 이유
#     - Lab 사각형을 그리는 함수 작성하기
#     - Lab 구조화 프로그래밍 실습
# - 5.8 순환 호출
#     - Lab 프랙탈 그래픽
# - 5.9 변수의 범위
#     - Lab 함수 그리기
#     - Lab 막대 그래프 그리기

# %% [markdown]
# 학습목표
# - 함수의 개념을 학습합니다.
# - 함수를 작성하는 방법을 학습합니다.
# - 함수를 호출하여 사용하여 방법을 학습합니다.

# %% [markdown]
# ## 5.1 이번 장에서 만들 프로그램

# %% [markdown]
# ## 5.2 함수란?

# %% [markdown]
# 관련 있는 코드들을 묶어서 전체 프로그램을 조직화할 필요가 있다.
#
# 코드를 묶는 3가지의 방법
# - 함수(function)는 우리가 반복적으로 사용하는 코드를 묶은 것으로 프로그램의 빌딩 블록과 같다.
# - 객체(object)는 서로 관련 있는 변수와 함수를 묶는 방법이다.
# - 모듈(module)은 함수나 객체들을 소스 파일 안에 모은 것이다

# %% [markdown]
# ### 함수
#
# 함수(function)는 특정 작업을 수행하는 명령어들의 모음에 이름을 붙인 것이다.
#
# 함수는 작업에 필요한 데이터를 전달받을 수 있으며, 작업이 완료된 후에는 작업의 결과를 호출자에게 반환할 수 있다.
#
# ![image.png](attachment:660e4c6e-7d72-4979-97e0-8b552d605aee.png)

# %% [markdown]
# ### 함수의 필요성
#
# 프로그램을 작성하다 보면 동일한 처리를 반복해야 하는 경우가 많이 발생한다.
#
# 이런 경우에는, 이미 작성한 코드를 재활용하여 사용할 수 있으면 정말 좋을 것이다
#
# 함수를 이용하면 우리가 여러 번 반복해야 되는 처리 단계를 하나로 모아서 필요할 때 언제든지 호출하여 사용할 수 있다.

# %% [markdown]
# ## 5.3 함수 작성하고 호출하기

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 함수 호출
#
# 함수 호출(function call)이란 get_area()과 같이 함수의 이름을 써주는 것이다.
#
# 함수가 호출되면 함수 안에 있는 문장들이 실행되며 실행이 끝나면 호출한 위치로 되돌아간다.
#
# ![image.png](attachment:e0622ae2-169d-489d-af27-30f2909e4303.png)

# %% [markdown]
# ### 함수에 값 전달하기
# - 함수에 값(정보)을 전달할 수 있는데 이 값을 인수(argument)라고 함
#     - 아래 예에서 get_area(3) 호출에서 '3'이 인수가 됨
# - 인수를 전달받는 변수를 매개 변수(parameter)라고 함
#     - 호출되는 함수 get_area(radius)에서 이 값('3')을 전달받는 변수 radius가 매개 변수가 됨
#
#      ![image.png](attachment:5ef56acf-e25d-4ab9-98e8-f14993eb794d.png)

# %%
def get_area(radius):      # 매개변수 radius
    area = 3.14*radius**2
    return area

result = get_area(3)   # 인수 argument
print("반지름이 3인 원의 면적=", result)
# Out:
# 반지름이 3인 원의 면적= 28.26

# %% [markdown]
# ### 값 반환하기
# - 함수로부터 되돌아오는 값을 반환 값이라고 함
#     - 함수가 값을 반환하려면 return 키워드를 사용하면 됨
#
#       ![image.png](attachment:113aa96b-9321-48d2-b5cf-fb78b97bc46e.png)

# %% [markdown]
# ### 서로 다른 인수로 호출될 수 있다.

# %%
def get_area(radius):
    area = 3.14*radius**2
    return area

result1 = get_area(3)
result2 = get_area(20)

print("반지름이 3인 원의 면적=", result1)
print("반지름이 20인 원의 면적=", result2)
# Out:
# 반지름이 3인 원의 면적= 28.26
# 반지름이 20인 원의 면적= 1256.0

# %% [markdown]
# ### 여러 개의 값 반환하기
# - 파이썬에서는 함수가 여러 개의 값을 반환할 수 있다.
# - 다음과 같은 형식을 사용한다. 이것은 7장에서 학습하는 튜플을 통하여 이루어진다.

# %%
def get_input():
    return 2, 3

x, y = get_input()		# x는 2이고 y는 3이다.

# %%
print(x)
print(y)
# Out:
# 2
# 3

# %% [markdown]
# ### 함수의 몸체는 나중에 작성할 수 있다.
# - 파이썬에서 함수의 헤더만 결정하고 몸체는 나중에 작성하고 싶은 경우에는 pass 키워드를 사용할 수 있다.

# %%
def sub():
    pass

# %% [markdown]
# ## 5.4 여러 개의 함수가 있는 프로그램
# - 파이썬은 인터프리트 언어이기 때문에 함수의 순서가 중요하다.
# - 함수 정의 및 명령문의 순서에 주의해야 함
#     - 함수를 호출하기 전에 반드시 함수를 정의해야 함

# %%
# 먼저 함수 정의를 제거하고 테스트
del get_area

# %%
result = get_area(3)   # <== 정의되지 않은 호출이 됨
print("반지름이 3인 원의 면적=", result)

def get_area(radius):    
    area = 3.14*radius**2
    return area
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 result = get_area(3)
#       2 print("반지름이 3인 원의 면적=", result)
#       4 def get_area(radius):
#
# NameError: name 'get_area' is not defined

# %% [markdown]
# 그러나 함수 내에서는 아직 정의되지 않은 함수를 호출할 수는 있다.
# - 프로그램의 실행 순서를 추적해 볼 것

# %%
# 먼저 함수 정의를 제거하고 테스트
del get_area

# %%
def main() :
    result1 = get_area(3)
    print("반지름이 3인 원의 면적=", result1)

def get_area(radius):
    area = 3.14*radius**2
    return area

main()
# Out:
# 반지름이 3인 원의 면적= 28.26

# %% [markdown]
# #### 추가학습: Doxygen과 같은 자동 주석 도구 사용법

# %% [markdown]
# ### Lab 피자 크기 비교
#
# 원의 반지름을 받아서 피자의 면적을 계산하는 함수를 작성해서 사용해보자.
#
# ![image.png](attachment:ca298c1f-38a7-4dda-b81a-3c3c4f5830b5.png)

# %%
# %load pizza_.py
def main() : 
    print("20cm 피자 2개의 면적:", get_area(20)+get_area(20))
    print("30cm 피자 1개의 면적:", get_area(30))

## 원의 면적을 계산한다.
# @param radius 원의 반지름
# @return 원의 면적 
#
def get_area(radius) :
    if radius > 0 :
        area = 3.14*radius**2
    else :
        area = 0
    return area

main()
# Out:
# 20cm 피자 2개의 면적: 2512.0
# 30cm 피자 1개의 면적: 2826.0

# %% [markdown]
# ## 5.5 매개 변수 전달
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 서로 다른 인수로 호출될 수 있다.

# %%
def get_sum(start, end):
    sum = 0
    for i in range(start, end+1):
        sum += i
    return sum



# 1과 10이 get_sum()의 인수가 된다. 
x = get_sum(1, 10)  

# 1과 20이 get_sum()의 인수가 된다. 
y = get_sum(1, 20);  


print(x)
print(y)
# Out:
# 55
# 210

# %% [markdown]
# #### 매개 변수를 변경한다고 해서 인수가 변경되지 않는다.

# %%
def set_radius(radius):
    radius = 100
    return

r = 20
set_radius(r)
print(r)
# Out:
# 20

# %% [markdown]
# ### 디폴트 인수
#
# 파이썬에서는 함수의 매개 변수가 기본값을 가질 수 있다. 이것을 디폴트 인수(default argument)라고 한다.

# %%
def greet(name, msg="별일없죠?"):
    print("안녕 ", name + ', ' + msg)

greet("영희")
# Out:
# 안녕  영희, 별일없죠?

# %% [markdown]
# ### 인수 전달 방식

# %%
def sub(x, y, z):
    print("x=", x, "y=", y, "z=", z)

# %% [markdown]
# #### 위치 인수 (positional argument): 기본 인수 전달 방식
# - 순서대로 전달 됨

# %%
sub(10, 20, 30)
# Out:
# x= 10 y= 20 z= 30

# %% [markdown]
# #### 키워드 인수 (keyword argument): 인수의 이름을 명시적으로 지정해서 값을 매개 변수로 전달하는 방법
# - 순서를 맞추지 않아도 됨

# %%
sub(x=10, y=20, z=30)
# Out:
# x= 10 y= 20 z= 30

# %%
sub(y=20, x=10, z=30)
# Out:
# x= 10 y= 20 z= 30

# %% [markdown]
# 위치 인수와 키워드 인수가 섞일 수 있음
# - 반드시 위치 인수가 키워드 인수 앞에 나와야 함

# %%
sub(10, y=20, z=30)
# Out:
# x= 10 y= 20 z= 30

# %%
sub(x=10, 20, 30)  # SyntaxError: positional argument follows keyword argument
# Out:
#   Input In [25]
#     sub(x=10, 20, 30)
#                     ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# #### 가변 인수
# - 함수는 전달하는 값이 몇 개 인지 모름
# - 함수 안에서 전달되는 값의 개수를 파악할 수 있음

# %%
def varfunc(*args ): 
    print (args)

print("하나의 값으로 호출")
varfunc(10)

print("여러 개의 값으로 호출")
varfunc(10, 20, 30)
# Out:
# 하나의 값으로 호출
# (10,)
# 여러 개의 값으로 호출
# (10, 20, 30)

# %% [markdown]
# 전달하는 모든 값의 합을 계산하는 함수 add()

# %%
def add(*numbers) :
    sum = 0
    for n in numbers:
        sum = sum + n
    return sum

print(add(10, 20))
print(add(10, 20, 30))
# Out:
# 30
# 60

# %% [markdown]
# 매개 변수 이름 앞에 이중 별표(**)를 사용하여 가변 길이 키워드 인수를 나타낸다.
# - 인수는 딕셔너리 형태로 전달된다

# %%
def myfunc(**kwargs):
    result = ""
    for arg in kwargs.values():
        result += arg
    return result


print(myfunc(a="Hi!", b="Mr.", c="Kim"))
# Out:
# Hi!Mr.Kim

# %% [markdown]
# ### *연산자로 언패킹하기
#
# - 단일 별표 연산자 *는 파이썬이 제공하는 모든 반복 가능한 객체(iterable)을 언패킹할 수 있고
# - 이중 별표 연산자 **는 딕셔너리 객체를 언패킹할 수 있다.
#
#     ![image.png](attachment:6f8ae10a-dbbc-499c-9c97-06f2f7e27fbe.png)

# %%
alist = [ 1 , 2 , 3 ] 
print(*alist)   # unpacking
# Out:
# 1 2 3

# %%
alist = [ 1 , 2 , 3 ] 
print(alist)
# Out:
# [1, 2, 3]

# %% [markdown]
# 언패킹에서 개수는 맞춰야 함

# %%
def sum(a, b, c):
    print(a + b + c)

alist = [1, 2, 3]
sum(*alist)
# Out:
# 6

# %% [markdown]
# ### Lab 환영 문자열 출력 함수
#
# 전광판에 “환영합니다” 문자열을 여러 번 출력하는 함수 display(msg, count)를 작성해보자.

# %%
##
#	이 프로그램은 메시지를 반복하여 출력한다. 
#
def display(msg, count=1) :
    for k in range(count) :
        print(msg)

display("환영합니다.", 5)
# Out:
# 환영합니다.
# 환영합니다.
# 환영합니다.
# 환영합니다.
# 환영합니다.

# %% [markdown]
# ### Lab 이분법
#
# - 구간 [a, b]에서 f(a)f(b) < 0이라고 하자. f(a)f(b) < 0이면 함수 f는 반드시 구간 [a,b]에서 근을 가져야 한다. 계속해서 a와 b의 중간값 m=(a+b)/2을 계산하고, 함수 f(m)의 값을 계산한다.
# - f(a)f(m) < 0이면 근은 [a, m] 사이에 있고, 그렇지 않으면 근은 [m, b] 구간에 있을 것이다
# ![image.png](attachment:1102efd6-f080-42e0-a0c2-cf380fae80a4.png)

# %%
# %load bisection_.py
##
#	이 프로그램은 이분법을 구현한다. 
#

# 함수를 정의한다. 
def f(x):
    return(x**2-x-1)

def bisection_method(a, b, error):
    if f(a)*f(b) > 0:
        print("구간에서 근을 찾을 수 없습니다.")
    else:
        while (b - a)/2.0 > error:	# 오차를 계산한다. 
            midpoint = (a + b)/2.0	# 중점을 계산한다. 
            if f(midpoint) == 0:
                return(midpoint) 
            elif f(a)*f(midpoint) < 0: 
                b = midpoint
            else:
                a = midpoint
        
        return(midpoint)

answer = bisection_method(1, 2, 0.0001)

print("x**2-x-1의 근:", answer)
# Out:
# x**2-x-1의 근: 1.6180419921875

# %% [markdown]
# ### Lab 주급 계산 프로그램
#
# 주단위로 봉급을 받는 알바생이 있다고 하자. 현재 시급과 일한 시간을 입력하면 주급을 계산해주는 함수 weeklyPay(rate, hour)를 만들고 이 함수를 호출하여 주급을 출력하는 프로그램을 작성해보자. 30시간이 넘는 근무 시간에 대해서는 시급의 1.5배를 지급한다고 하자.

# %%
# %load cal_pay_.py
##
#	이 프로그램은 주급을 계산한다. 
#

def weeklyPay( rate, hour ): 
    money = 0
    if (hour > 30): 
        money = rate*30 + 1.5*rate*(hour-30)
    else: 
        money = rate*hour
    return money

rate = int(input("시급을 입력하시오:"))   # 10000
hour = int(input("근무 시간을  입력하시오:")) # 38
print("주급은 " + str(weeklyPay(rate, hour)))
# Out:
# 시급을 입력하시오:10000
# 근무 시간을  입력하시오:38
# 주급은 420000.0

# %% [markdown]
# ## 5.6 값 반환하기
#
# - 파이썬에서 return 문이 처리되면 함수가 즉시 종료됨
#     - 함수에서 예외적인 경우를 처리하는데 이 기능을 사용하기도 함
#
# - 모든 경우에 값을 반환하는 것이 좋다.

# %% [markdown]
# radius가 음수일 때는 아무것도 반환되지 않는다.

# %%
def get_area(radius) :
    if radius > 0 :
        return 3.14*radius**2        # radius가 음수일 때는 아무것도 반환되지 않는다.

# %% [markdown]
# 하나의 함수에 여러 개의 return 문장이 있으면 이해하기 어려울 수 있음

# %%
def get_area(radius) :
    if radius > 0 :
        return 3.14*radius**2
    else :
        area = 0
    
    return area

# %% [markdown]
# 하나의 변수에 반환값을 저장했다가 마지막에 return 문장을 사용하여 값을 반환

# %%
def get_area(radius) :
    if radius > 0 :
        return 3.14*radius**2
    else :
        return 0

# %% [markdown]
# ### 여러 개의 값 반환하기
#
# 파이썬에서는 함수가 하나 이상의 값도 반환할 수 있다.
# - 튜플로 반환
#
# ![image.png](attachment:844af74a-b217-4a19-8ec6-d2607107761e.png)

# %%
def sub():
    return 1, 2, 3

a, b, c = sub()
print(a, b, c)
# Out:
# 1 2 3

# %% [markdown]
# ### 값을 반환하지 않는 함수
#
# return 문이 없을 경우, None이라는 특수 값을 반환함

# %%
def print_birthday(name):
    print("생일축하 합니다.! ")
    print("생일축하 합니다.! ")
    print("사랑하는 ", name, "의 ")
    print("생일축하 합니다.! ")
    
print_birthday("홍길동")
# Out:
# 생일축하 합니다.!
# 생일축하 합니다.!
# 사랑하는  홍길동 의
# 생일축하 합니다.!

# %%
result = print_birthday("홍길동")
print(result)
# Out:
# 생일축하 합니다.!
# 생일축하 합니다.!
# 사랑하는  홍길동 의
# 생일축하 합니다.!
# None

# %%
def print_birthday(name):
    if len(name) == 0:
        return
    
    print("생일축하 합니다.! ")
    print("생일축하 합니다.! ")
    print("사랑하는 ", name, "의 ")
    print("생일축하 합니다.! ")
    
print_birthday("홍길동")
# Out:
# 생일축하 합니다.!
# 생일축하 합니다.!
# 사랑하는  홍길동 의
# 생일축하 합니다.!

# %%
result = print_birthday("")
print(result)
# Out:
# None

# %% [markdown]
# ### Lab 여러 개의 값 반환
#
# 사용자로부터 이름과 나이를 입력받아서 동시에 반환하는 함수를 작성해보자.

# %%
# %load return_.py
##
#	이 프로그램은 사용자로부터 이름과 나이를 받아서 다시 출력한다. 
#
def get_info():
    name = input("이름:")   # 홍길동
    age = int(input("나이:"))  # 20
    return name, age		# 2개의 값을 반환한다. 
    
st_name, st_age = get_info()	# 반환된 값을 풀어서 변수에 저장한다.
print("이름은 ", st_name, "이고 나이는 ", st_age, "살입니다.")
# Out:
# 이름:홍길동
# 나이:20
# 이름은  홍길동 이고 나이는  20 살입니다.

# %% [markdown]
# ## 5.7 함수를 사용하는 이유
#
# - 소스 코드의 중복성을 없애준다.
# - 한번 제작된 함수는 다른 프로그램을 제작할 때도 사용이 가능하다.
# - 복잡한 문제를 단순한 부분으로 분해할 수 있다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Lab 사각형을 그리는 함수 작성하기
#
# Skip ...

# %%
# # %load draw_rect_.py
# ##
# #	이 프로그램은 사각형을 그리는 함수를 작성하고 사용한다. 
# #

# import turtle 
# t = turtle.Turtle()
# t.shape("turtle")

# def square(length):		# length는 한변의 길이
#     t.down()
#     for i in range(4):
#         t.forward(length)
#         t.left(90)
#     t.up()

# square(100);			# square() 함수를 호출한다. 
# t.forward(120)
# square(100);
# t.forward(120)
# square(100);

# turtle.mainloop()
# turtle.bye()

# %%
# %run draw_rect_.py

# %% [markdown]
# ### Lab 구조화 프로그래밍 실습
#
# 온도를 변환해주는 프로그램을 작성해보자.
# ![image.png](attachment:image.png)

# %%
# %load conv_temp_.py
##
#	이 프로그램은 온도를 변환한다. 
#
def menu() :
    print("1. 섭씨 온도->화씨 온도")
    print("2. 화씨 온도->섭씨 온도")
    print("3. 종료")
    selection = int(input("메뉴를 선택하세요: "))
    return selection

def ctof(c) :
    temp = c*9.0/5.0 + 32
    return temp

def ftoc(f) :
    temp = (f-32.0)*5.0/9.0
    return temp

def input_f() :
    f = float(input("화씨 온도를 입력하시오: "))
    return f

def input_c() :
    c = float(input("섭씨 온도를 입력하시오: "))
    return c

def main() :
    while True:
        index = menu()
        if index == 1 :
            t = input_c()
            t2 = ctof(t)
            print("화씨 온도 = ", t2, "\n")
        elif index == 2 :
            t = input_f()
            t2 = ftoc(t)
            print("섭씨 온도 = ", t2, "\n")
        else :
            break
main()
# Out:
# 1. 섭씨 온도->화씨 온도
# 2. 화씨 온도->섭씨 온도
# 3. 종료
# 메뉴를 선택하세요: 1
# 섭씨 온도를 입력하시오: 37
# 화씨 온도 =  98.6
#
# 1. 섭씨 온도->화씨 온도
# 2. 화씨 온도->섭씨 온도
# 3. 종료
# 메뉴를 선택하세요: 3

# %% [markdown]
# ## 5.8 순환 호출
#
# 순환(recursion)이란 어떤 알고리즘이나 함수가 자기 자신을 호출하여 문제를 해결하는 프로그래밍 기법이다.

# %% [markdown]
# 팩토리얼 계산 프로그램
# ![image.png](attachment:1284244b-3766-4ec4-bb8b-b94bf45d922b.png)

# %%
def  factorial(n):
    if n == 1 :
        return(1)
    else:
        return n * factorial(n-1)

n = eval(input("정수를 입력하시오:"))
print(n, "!= ", factorial(n))
# Out:
# 정수를 입력하시오:3
# 3 !=  6

# %% [markdown]
# ### Lab 프랙탈 그래픽
#
# Skip ...

# %%
# %run fractal_.py

# %% [markdown]
# ## 5.9 변수의 범위
#
# - 지역변수 (local variable): 함수 안에서 생성되는 변수
#     - 함수가 종료되면 사라지게 됨
# - 전역변수 (global variable): 함수의 외부에서 생성된 변수
#     - 프로그램의 어디서나 사용할 수 있음

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 지역변수

# %%
def myfunc():
    x = 100
    print(x)

myfunc()
# Out:
# 100

# %% [markdown]
# 전역변수

# %%
gx = 100

def myfunc():
    print(gx)

myfunc()
print(gx)
# Out:
# 100
# 100

# %% [markdown]
# ### 지역 변수는 함수마다 동일한 이름을 사용할 수 있다.

# %%
def myfunc() :
    x = 200
    print(x)

def main() :
    x = 100
    print(x)

myfunc()
main()
# Out:
# 200
# 100

# %% [markdown]
# ### 함수 안에서 전역 변수 변경하기

# %%
gx = 100

def myfunc() :
    gx = 200   # 함수 안에서 만들어진 새로운 지역변수 gx
    print(gx)

myfunc()
print(gx)   # 함수 밖의 전역변수는 그대로 있음
# Out:
# 200
# 100

# %% [markdown]
# ### 함수 안에서 전역변수의 값을 변경하고 싶으면
# - global 키워드를 사용해야 함

# %%
gx = 100

def myfunc() :
    global gx
    gx = 200   # 이제 gx 변수는 전역변수(global variable)임
    print(gx)

myfunc()
print(gx)   # 함수 밖의 전역변수는 그대로 있음
# Out:
# 200
# 200

# %% [markdown]
# ### Lab 함수 그리기
#
# 함수 f(x)=𝑥^2+1을 계산하는 함수를 작성하고 이 함수를 이용하여 화면에 f(x)를 그려보자.
#
# Skip ...

# %%
# %run draw_func_.py

# %% [markdown]
# ### Lab 막대 그래프 그리기
#
# 파이썬의 터틀 그래픽을 이용해서 막대 그래프를 그려보자.
#
# Skip ...

# %%
# %run draw_graph_.py

# %%
- 5장 종료 -
